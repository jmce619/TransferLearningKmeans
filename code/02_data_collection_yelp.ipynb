# %% [markdown]
# # Data Collection: Yelp

# %% [markdown]
# We used [Yelp Fusion API](https://www.yelp.com/developers/documentation/v3/get_started)'s [businesses/search path](https://www.yelp.com/developers/documentation/v3/business_search) and collected 30,293 business information from Yelp.

# %% [markdown]
# **Yelp Data Dictionary**
#
# | Name | Data Types (Pandas) | Description |
# |---|---|---|
# |id|object|a unique ID for each business, e.g. E8RJkjfdcwgtyoPMjQ_Olg|
# |alias |object|business name alias|
# |name|object|business name|
# |image_url|object|URL of photos taken at a given business|
# |is_closed|bool|True if the business is currently open, else False|
# |url|object|url of business listing on Yelp|
# |review_count|int64|Number of reviews|
# |categories|object|List of category title and alias pairs associated with this business|
# |rating|float64|Rating for this business (value ranges from 1, 1.5, ... 4.5, 5)|
# |coordinates|object|Coordinates of this business|
# |transactions|object|List of Yelp transactions that the business is registered for, such as pickup, delivery and restaurant_reservation.|
# |price|object|Price level of the business. Value is one of \\$, \\$\\$, \\$\\$\\$ and \\$\\$\\$\\$.|
# |location|object|Location of this business, including address, city, state, zip code and country.|
# |phone|object|phone number of the business|
# |display_phone|object|Phone number of the business formatted nicely to be displayed to users. The format is the standard phone number format for the business's country.|
# |distance|float64|Distance in meters from the search location. This returns meters regardless of the locale.|

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Collection:-Yelp" data-toc-modified-id="Data-Collection:-Yelp-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Collection: Yelp</a></span><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Create-constants" data-toc-modified-id="Create-constants-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Create constants</a></span></li><li><span><a href="#Define-function-to-provide-clean-list-of-zipcodes" data-toc-modified-id="Define-function-to-provide-clean-list-of-zipcodes-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Define function to provide clean list of zipcodes</a></span></li><li><span><a href="#Define-functions-to-fetch-businesses-from-Yelp-Funsion-API" data-toc-modified-id="Define-functions-to-fetch-businesses-from-Yelp-Funsion-API-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Define functions to fetch businesses from Yelp Funsion API</a></span></li><li><span><a href="#Fetch-data" data-toc-modified-id="Fetch-data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Fetch data</a></span></li><li><span><a href="#Export-results-as-.csv-file" data-toc-modified-id="Export-results-as-.csv-file-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Export results as .csv file</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import requests
import datetime as dt
import re
from pathlib import Path

# %% [markdown]
# ## Create constants
# - Create Yelp API key [here](https://www.yelp.com/developers/documentation/v3/authentication).
# - Save the API key as `.txt` file, create a directory with the path `"~/api_keys"`, and store the API key there.
# - To authenticate API calls with the API Key, set the Authorization HTTP header value as `Bearer API_KEY`.

# %%
with open(str(Path.home() / 'api_keys/yelp_fusion.txt')) as file:
    API_KEY = file.read().replace('\n', '')
HEADERS = {'Authorization': 'bearer %s' % API_KEY}
URL = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# - By default, Yelp allows [5,000 calls per day](https://www.yelp.com/developers/faq).
# - Limit: Number of business results to return. By default, it will return 20. Maximum is 50.
# - Offset: Using the offset and limit parameters, Yelp allows up to 1000 businesses from this endpoint if there are more than 1000 results. If one requests a page out of this 1000 business limit, this endpoint will return an error. Therefore, MAX_ITEMS_PER_SEARCH is set to be 1000.

# %%
API_CALL_LIMIT = 5_000
RESULTS_LIMIT = 50
MAX_ITEMS_PER_SEARCH = 1_000

# %% [markdown]
# ## Define function to provide clean list of zipcodes

# %%
def zipcodes(zipcode_file):
    '''
    Processes .txt file
    Returns a set of zipcodes
    '''
    with open(f'../data/{zipcode_file}.txt') as file:
        zipcodes = {i.replace('\n', '') for i in file.readlines() if 'PO BOX' not in i}
        zipcodes = {re.match(r"(^[0-9]*).*", i).group(1) for i in zipcodes}
    return zipcodes

# %% [markdown]
# ## Define functions to fetch businesses from Yelp Funsion API

# %%
def single_request(location, offset=1):
    '''
    Searches businesses for one given location
    Returns a tuple: 
        A boolean value: True if no errors in the request, otherwise False 
        A list of businesses starting at the given offset, or the response if there is an error
    Number of results is limited to RESULTS_LIMIT
    '''
    params = {'location': location,
              'limit': RESULTS_LIMIT,
              'offset': offset}
    response = requests.get(url=URL, params=params, headers=HEADERS)
    
    if response.status_code != 200:
        print(f"Request failed with {response.text}")
        return (False, response)
    else:
        data = response.json()
        if 'error' in data:
            print(f'Error occured in response {data}')
            return (False, response)
        else:
            return (True, data)

# %%
def businesses_by_location(location):
    '''
    Searches business by one given location
    Sends out multipule requests
    Number of results is limited to MAX_ITEMS_PER_SEARCH
    Note: there might be more businesses than MAX_ITEMS_PER_SEARCH, 
    but Yelp only provides up to MAX_ITEMS_PER_SEARCH per location.
    '''
    offset = 1
    all_results = []
    
    for i in range(MAX_ITEMS_PER_SEARCH // RESULTS_LIMIT):
        succeeded, data = single_request(location, offset=(RESULTS_LIMIT * i))
                    
        if succeeded is False:
            print('Error occured in single_request, Abort!')
            return all_results
        else:
            businesses = data['businesses']
            all_results.extend(businesses)
            
            # If the amount of businesses returned by single_request() is greater or equal to RESULTS_LIMIT,
            # Then there are more results to fetch 
            if len(businesses) >= RESULTS_LIMIT:
                # Pause to slow down frequency of requests before next iteration
                time.sleep(.5)
            else:
                # If there is fewer results than the RESULTS_LIMIT, we exhausted the results.
                break

    print(f'Searched: {location}')
    print(f'    Total available search results: {data["total"]}')
    print(f'    Total amount of businesses collected: {len(all_results)}')
    return all_results

# %%
def businesses_by_multiple_locations(locations):
    '''
    Searches business by a list of locations
    Returns a Pandas dataframe of unique businesses 
    '''
    unique_business_dict = dict()
    
    # Collects business by ID to ensure results are unique.
    for location in locations:
        businesses = businesses_by_location(location)
        for business in businesses:
            unique_business_dict[business['id']] = business
            
    print('Query completed at: ' + dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
    return pd.DataFrame(unique_business_dict.values())

# %% [markdown]
# ## Fetch data

# %%
zipcodes = zipcodes('zipcodes')

# %%
results = businesses_by_multiple_locations(zipcodes)
# Out:
# Total Avaible Search Result: 737
# Query Completion Time and Date: 2020-02-08 00:04:53
# Total Avaible Search Result: 316
# Query Completion Time and Date: 2020-02-08 00:05:02
# Total Avaible Search Result: 198
# Query Completion Time and Date: 2020-02-08 00:05:07
# Total Avaible Search Result: 9
# Query Completion Time and Date: 2020-02-08 00:05:07
# Total Avaible Search Result: 10
# Query Completion Time and Date: 2020-02-08 00:05:08
# Total Avaible Search Result: 854
# Query Completion Time and Date: 2020-02-08 00:05:32
# Total Avaible Search Result: 964
# Query Completion Time and Date: 2020-02-08 00:05:58
# Total Avaible Search Result: 764
# Query Completion Time and Date: 2020-02-08 00:06:20
# Total Avaible Search Result: 1500
# Query Completion Time and Date: 2020-02-08 00:06:51
# Total Avaible Search Result: 5500
# Query Completion Time and Date: 2020-02-08 00:07:22
# Total Avaible Search Result: 312
# Query Completion Time and Date: 2020-02-08 00:07:31
# Total Avaible Search Result: 2200
# Query Completion Time and Date: 2020-02-08 00:08:02
# Total Avaible Search Result: 18
# Query Completion Time and Date: 2020-02-08 00:08:02
# Total Avaible Search Result: 1800
# Query Completion Time and Date: 2020-02-08 00:08:34
# Total Avaible Search Result: 9200
# Query Completion Time and Date: 2020-02-08 00:09:06
# Total Avaible Search Result: 2600
# Query Completion Time and Date: 2020-02-08 00:09:38
# Total Avaible Search Result: 7
# Query Completion Time and Date: 2020-02-08 00:09:38
# Total Avaible Search Result: 385
# Query Completion Time and Date: 2020-02-08 00:09:48
# Total Avaible Search Result: 292
# Query Completion Time and Date: 2020-02-08 00:09:55
# Total Avaible Search Result: 494
# Query Completion Time and Date: 2020-02-08 00:10:08
# Total Avaible Search Result: 2000
# Query Completion Time and Date: 2020-02-08 00:10:38
# Total Avaible Search Result: 265
# Query Completion Time and Date: 2020-02-08 00:10:47
# Total Avaible Search Result: 30
# Query Completion Time and Date: 2020-02-08 00:10:47
# Total Avaible Search Result: 874
# Query Completion Time and Date: 2020-02-08 00:11:12
# Total Avaible Search Result: 381
# Query Completion Time and Date: 2020-02-08 00:11:23
# Total Avaible Search Result: 7
# Query Completion Time and Date: 2020-02-08 00:11:24
# Total Avaible Search Result: 3800
# Query Completion Time and Date: 2020-02-08 00:11:55
# Total Avaible Search Result: 352
# Query Completion Time and Date: 2020-02-08 00:12:06
# Total Avaible Search Result: 570
# Query Completion Time and Date: 2020-02-08 00:12:23
# Total Avaible Search Result: 6100
# Query Completion Time and Date: 2020-02-08 00:12:55
# Total Avaible Search Result: 266
# Query Completion Time and Date: 2020-02-08 00:13:02
# Total Avaible Search Result: 585
# Query Completion Time and Date: 2020-02-08 00:13:17
# Total Avaible Search Result: 1400
# Query Completion Time and Date: 2020-02-08 00:13:45
# Total Avaible Search Result: 46
# Query Completion Time and Date: 2020-02-08 00:13:46
# Total Avaible Search Result: 114
# Query Completion Time and Date: 2020-02-08 00:13:50
# Total Avaible Search Result: 373
# Query Completion Time and Date: 2020-02-08 00:14:01
# Total Avaible Search Result: 2400
# Query Completion Time and Date: 2020-02-08 00:14:29
# Total Avaible Search Result: 847
# Query Completion Time and Date: 2020-02-08 00:14:53
# Total Avaible Search Result: 1900
# Query Completion Time and Date: 2020-02-08 00:15:23
# Total Avaible Search Result: 2200
# Query Completion Time and Date: 2020-02-08 00:15:51
# Total Avaible Search Result: 55
# Query Completion Time and Date: 2020-02-08 00:15:53
# Total Avaible Search Result: 1200
# Query Completion Time and Date: 2020-02-08 00:16:21
# Total Avaible Search Result: 2000
# Query Completion Time and Date: 2020-02-08 00:16:52
# Total Avaible Search Result: 174
# Query Completion Time and Date: 2020-02-08 00:16:57
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 00:17:28
# Total Avaible Search Result: 1600
# Query Completion Time and Date: 2020-02-08 00:17:58
# Total Avaible Search Result: 198
# Query Completion Time and Date: 2020-02-08 00:18:03
# Total Avaible Search Result: 33
# Query Completion Time and Date: 2020-02-08 00:18:03
# Total Avaible Search Result: 215
# Query Completion Time and Date: 2020-02-08 00:18:11
# Total Avaible Search Result: 712
# Query Completion Time and Date: 2020-02-08 00:18:30
# Total Avaible Search Result: 695
# Query Completion Time and Date: 2020-02-08 00:18:49
# Total Avaible Search Result: 239
# Query Completion Time and Date: 2020-02-08 00:18:54
# Total Avaible Search Result: 2100
# Query Completion Time and Date: 2020-02-08 00:19:25
# Total Avaible Search Result: 292
# Query Completion Time and Date: 2020-02-08 00:19:32
# Total Avaible Search Result: 578
# Query Completion Time and Date: 2020-02-08 00:19:48
# Total Avaible Search Result: 234
# Query Completion Time and Date: 2020-02-08 00:19:55
# Total Avaible Search Result: 12
# Query Completion Time and Date: 2020-02-08 00:19:55
# Total Avaible Search Result: 878
# Query Completion Time and Date: 2020-02-08 00:20:19
# Total Avaible Search Result: 49
# Query Completion Time and Date: 2020-02-08 00:20:20
# Total Avaible Search Result: 6100
# Query Completion Time and Date: 2020-02-08 00:20:53
# Total Avaible Search Result: 2800
# Query Completion Time and Date: 2020-02-08 00:21:22
# Total Avaible Search Result: 545
# Query Completion Time and Date: 2020-02-08 00:21:36
# Total Avaible Search Result: 2100
# Query Completion Time and Date: 2020-02-08 00:22:06
# Total Avaible Search Result: 307
# Query Completion Time and Date: 2020-02-08 00:22:14
# Total Avaible Search Result: 339
# Query Completion Time and Date: 2020-02-08 00:22:23
# Total Avaible Search Result: 939
# Query Completion Time and Date: 2020-02-08 00:22:47
# Total Avaible Search Result: 754
# Query Completion Time and Date: 2020-02-08 00:23:07
# Total Avaible Search Result: 4600
# Query Completion Time and Date: 2020-02-08 00:23:39
# Total Avaible Search Result: 618
# Query Completion Time and Date: 2020-02-08 00:23:56
# Total Avaible Search Result: 1500
# Query Completion Time and Date: 2020-02-08 00:24:25
# Total Avaible Search Result: 199
# Query Completion Time and Date: 2020-02-08 00:24:30
# Total Avaible Search Result: 7
# Query Completion Time and Date: 2020-02-08 00:24:30
# Total Avaible Search Result: 198
# Query Completion Time and Date: 2020-02-08 00:24:35
# Total Avaible Search Result: 624
# Query Completion Time and Date: 2020-02-08 00:24:53
# Total Avaible Search Result: 545
# Query Completion Time and Date: 2020-02-08 00:25:09
# Total Avaible Search Result: 3400
# Query Completion Time and Date: 2020-02-08 00:25:38
# Total Avaible Search Result: 1600
# Query Completion Time and Date: 2020-02-08 00:26:05
# Total Avaible Search Result: 575
# Query Completion Time and Date: 2020-02-08 00:26:22
# Total Avaible Search Result: 11
# Query Completion Time and Date: 2020-02-08 00:26:22
# Total Avaible Search Result: 60
# Query Completion Time and Date: 2020-02-08 00:26:24
# Total Avaible Search Result: 929
# Query Completion Time and Date: 2020-02-08 00:26:51
# Total Avaible Search Result: 2300
# Query Completion Time and Date: 2020-02-08 00:27:22
# Total Avaible Search Result: 581
# Query Completion Time and Date: 2020-02-08 00:27:37
# Total Avaible Search Result: 1000
# Query Completion Time and Date: 2020-02-08 00:28:05
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 00:28:37
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 00:29:08
# Total Avaible Search Result: 6000
# Query Completion Time and Date: 2020-02-08 00:29:40
# Total Avaible Search Result: 303
# Query Completion Time and Date: 2020-02-08 00:29:49
# Total Avaible Search Result: 780
# Query Completion Time and Date: 2020-02-08 00:30:11
# Total Avaible Search Result: 959
# Query Completion Time and Date: 2020-02-08 00:30:38
# Total Avaible Search Result: 457
# Query Completion Time and Date: 2020-02-08 00:30:51
# Total Avaible Search Result: 533
# Query Completion Time and Date: 2020-02-08 00:31:05
# Total Avaible Search Result: 520
# Query Completion Time and Date: 2020-02-08 00:31:19
# Total Avaible Search Result: 78
# Query Completion Time and Date: 2020-02-08 00:31:21
# Total Avaible Search Result: 88
# Query Completion Time and Date: 2020-02-08 00:31:23
# Total Avaible Search Result: 568
# Query Completion Time and Date: 2020-02-08 00:31:38
# Total Avaible Search Result: 34
# Query Completion Time and Date: 2020-02-08 00:31:38
# Total Avaible Search Result: 6200
# Query Completion Time and Date: 2020-02-08 00:32:11
# Total Avaible Search Result: 34
# Query Completion Time and Date: 2020-02-08 00:32:12
# Total Avaible Search Result: 2500
# Query Completion Time and Date: 2020-02-08 00:32:43
# Total Avaible Search Result: 224
# Query Completion Time and Date: 2020-02-08 00:32:49
# Total Avaible Search Result: 55
# Query Completion Time and Date: 2020-02-08 00:32:51
# Total Avaible Search Result: 528
# Query Completion Time and Date: 2020-02-08 00:33:06
# Total Avaible Search Result: 733
# Query Completion Time and Date: 2020-02-08 00:33:26
# Total Avaible Search Result: 2400
# Query Completion Time and Date: 2020-02-08 00:33:56
# Total Avaible Search Result: 1800
# Query Completion Time and Date: 2020-02-08 00:34:25
# Total Avaible Search Result: 2200
# Query Completion Time and Date: 2020-02-08 00:34:55
# Total Avaible Search Result: 1100
# Query Completion Time and Date: 2020-02-08 00:35:23
# Total Avaible Search Result: 19
# Query Completion Time and Date: 2020-02-08 00:35:23
# Total Avaible Search Result: 1000
# Query Completion Time and Date: 2020-02-08 00:35:51
# Total Avaible Search Result: 3400
# Query Completion Time and Date: 2020-02-08 00:36:23
# Total Avaible Search Result: 1500
# Query Completion Time and Date: 2020-02-08 00:36:51
# Total Avaible Search Result: 7
# Query Completion Time and Date: 2020-02-08 00:36:52
# Total Avaible Search Result: 89
# Query Completion Time and Date: 2020-02-08 00:36:54
# Total Avaible Search Result: 2700
# Query Completion Time and Date: 2020-02-08 00:37:25
# Total Avaible Search Result: 2900
# Query Completion Time and Date: 2020-02-08 00:37:54
# Total Avaible Search Result: 76
# Query Completion Time and Date: 2020-02-08 00:37:56
# Total Avaible Search Result: 23
# Query Completion Time and Date: 2020-02-08 00:37:57
# Total Avaible Search Result: 44
# Query Completion Time and Date: 2020-02-08 00:37:57
# Total Avaible Search Result: 2300
# Query Completion Time and Date: 2020-02-08 00:38:27
# Total Avaible Search Result: 1600
# Query Completion Time and Date: 2020-02-08 00:38:55
# Total Avaible Search Result: 398
# Query Completion Time and Date: 2020-02-08 00:39:04
# Total Avaible Search Result: 1500
# Query Completion Time and Date: 2020-02-08 00:39:34
# Total Avaible Search Result: 704
# Query Completion Time and Date: 2020-02-08 00:39:53
# Total Avaible Search Result: 3600
# Query Completion Time and Date: 2020-02-08 00:40:25
# Total Avaible Search Result: 6000
# Query Completion Time and Date: 2020-02-08 00:40:57
# Total Avaible Search Result: 6300
# Query Completion Time and Date: 2020-02-08 00:41:30
# Total Avaible Search Result: 282
# Query Completion Time and Date: 2020-02-08 00:41:37
# Total Avaible Search Result: 323
# Query Completion Time and Date: 2020-02-08 00:41:47
# Total Avaible Search Result: 5400
# Query Completion Time and Date: 2020-02-08 00:42:20
# Total Avaible Search Result: 6500
# Query Completion Time and Date: 2020-02-08 00:42:52
# Total Avaible Search Result: 1200
# Query Completion Time and Date: 2020-02-08 00:43:21
# Total Avaible Search Result: 671
# Query Completion Time and Date: 2020-02-08 00:43:39
# Total Avaible Search Result: 1800
# Query Completion Time and Date: 2020-02-08 00:44:08
# Total Avaible Search Result: 680
# Query Completion Time and Date: 2020-02-08 00:44:26
# Total Avaible Search Result: 2200
# Query Completion Time and Date: 2020-02-08 00:44:56
# Total Avaible Search Result: 17700
# Query Completion Time and Date: 2020-02-08 00:45:28
# Total Avaible Search Result: 13
# Query Completion Time and Date: 2020-02-08 00:45:29
# Total Avaible Search Result: 1100
# Query Completion Time and Date: 2020-02-08 00:45:57
# Total Avaible Search Result: 558
# Query Completion Time and Date: 2020-02-08 00:46:13
# Total Avaible Search Result: 487
# Query Completion Time and Date: 2020-02-08 00:46:26
# Total Avaible Search Result: 1000
# Query Completion Time and Date: 2020-02-08 00:46:55
# Total Avaible Search Result: 914
# Query Completion Time and Date: 2020-02-08 00:47:21
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 00:47:54
# Total Avaible Search Result: 472
# Query Completion Time and Date: 2020-02-08 00:48:06
# Total Avaible Search Result: 74
# Query Completion Time and Date: 2020-02-08 00:48:08
# Total Avaible Search Result: 327
# Query Completion Time and Date: 2020-02-08 00:48:17
# Total Avaible Search Result: 20
# Query Completion Time and Date: 2020-02-08 00:48:18
# Total Avaible Search Result: 2100
# Query Completion Time and Date: 2020-02-08 00:48:48
# Total Avaible Search Result: 713
# Query Completion Time and Date: 2020-02-08 00:49:06
# Total Avaible Search Result: 67
# Query Completion Time and Date: 2020-02-08 00:49:08
# Total Avaible Search Result: 5900
# Query Completion Time and Date: 2020-02-08 00:49:40
# Total Avaible Search Result: 6500
# Query Completion Time and Date: 2020-02-08 00:50:13
# Total Avaible Search Result: 5900
# Query Completion Time and Date: 2020-02-08 00:50:46
# Total Avaible Search Result: 373
# Query Completion Time and Date: 2020-02-08 00:50:56
# Total Avaible Search Result: 83
# Query Completion Time and Date: 2020-02-08 00:50:58
# Total Avaible Search Result: 25
# Query Completion Time and Date: 2020-02-08 00:50:59
# Total Avaible Search Result: 1200
# Query Completion Time and Date: 2020-02-08 00:51:27
# Total Avaible Search Result: 424
# Query Completion Time and Date: 2020-02-08 00:51:38
# Total Avaible Search Result: 6300
# Query Completion Time and Date: 2020-02-08 00:52:10
# Total Avaible Search Result: 6300
# Query Completion Time and Date: 2020-02-08 00:52:42
# Total Avaible Search Result: 3200
# Query Completion Time and Date: 2020-02-08 00:53:14
# Total Avaible Search Result: 1200
# Query Completion Time and Date: 2020-02-08 00:53:42
# Total Avaible Search Result: 1000
# Query Completion Time and Date: 2020-02-08 00:54:10
# Total Avaible Search Result: 8
# Query Completion Time and Date: 2020-02-08 00:54:10
# Total Avaible Search Result: 587
# Query Completion Time and Date: 2020-02-08 00:54:26
# Total Avaible Search Result: 5900
# Query Completion Time and Date: 2020-02-08 00:54:58
# Total Avaible Search Result: 38
# Query Completion Time and Date: 2020-02-08 00:54:58
# Total Avaible Search Result: 2100
# Query Completion Time and Date: 2020-02-08 00:55:27
# Total Avaible Search Result: 5200
# Query Completion Time and Date: 2020-02-08 00:55:59
# Total Avaible Search Result: 26
# Query Completion Time and Date: 2020-02-08 00:56:00
# Total Avaible Search Result: 998
# Query Completion Time and Date: 2020-02-08 00:56:26
# Total Avaible Search Result: 479
# Query Completion Time and Date: 2020-02-08 00:56:38
# Total Avaible Search Result: 94
# Query Completion Time and Date: 2020-02-08 00:56:40
# Total Avaible Search Result: 570
# Query Completion Time and Date: 2020-02-08 00:56:56
# Total Avaible Search Result: 12
# Query Completion Time and Date: 2020-02-08 00:56:56
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 00:57:27
# Total Avaible Search Result: 398
# Query Completion Time and Date: 2020-02-08 00:57:37
# Total Avaible Search Result: 5800
# Query Completion Time and Date: 2020-02-08 00:58:09
# Total Avaible Search Result: 542
# Query Completion Time and Date: 2020-02-08 00:58:23
# Total Avaible Search Result: 1000
# Query Completion Time and Date: 2020-02-08 00:58:50
# Total Avaible Search Result: 241
# Query Completion Time and Date: 2020-02-08 00:58:57
# Total Avaible Search Result: 921
# Query Completion Time and Date: 2020-02-08 00:59:21
# Total Avaible Search Result: 2100
# Query Completion Time and Date: 2020-02-08 00:59:50
# Total Avaible Search Result: 9
# Query Completion Time and Date: 2020-02-08 00:59:51
# Total Avaible Search Result: 705
# Query Completion Time and Date: 2020-02-08 01:00:10
# Total Avaible Search Result: 6300
# Query Completion Time and Date: 2020-02-08 01:00:43
# Total Avaible Search Result: 124
# Query Completion Time and Date: 2020-02-08 01:00:46
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 01:01:17
# Total Avaible Search Result: 1100
# Query Completion Time and Date: 2020-02-08 01:01:45
# Total Avaible Search Result: 822
# Query Completion Time and Date: 2020-02-08 01:02:08
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 01:02:40
# Total Avaible Search Result: 5900
# Query Completion Time and Date: 2020-02-08 01:03:12
# Total Avaible Search Result: 19
# Query Completion Time and Date: 2020-02-08 01:03:13
# Total Avaible Search Result: 982
# Query Completion Time and Date: 2020-02-08 01:03:39
# Total Avaible Search Result: 210
# Query Completion Time and Date: 2020-02-08 01:03:45
# Total Avaible Search Result: 453
# Query Completion Time and Date: 2020-02-08 01:03:59
# Total Avaible Search Result: 1300
# Query Completion Time and Date: 2020-02-08 01:04:29
# Total Avaible Search Result: 4900
# Query Completion Time and Date: 2020-02-08 01:05:01
# Total Avaible Search Result: 20
# Query Completion Time and Date: 2020-02-08 01:05:02
# Total Avaible Search Result: 1300
# Query Completion Time and Date: 2020-02-08 01:05:31
# Total Avaible Search Result: 6300
# Query Completion Time and Date: 2020-02-08 01:06:04
# Total Avaible Search Result: 3200
# Query Completion Time and Date: 2020-02-08 01:06:32
# Total Avaible Search Result: 1500
# Query Completion Time and Date: 2020-02-08 01:07:02
# Total Avaible Search Result: 999
# Query Completion Time and Date: 2020-02-08 01:07:30
# Total Avaible Search Result: 20
# Query Completion Time and Date: 2020-02-08 01:07:30
# Total Avaible Search Result: 1600
# Query Completion Time and Date: 2020-02-08 01:07:58
# Total Avaible Search Result: 5700
# Query Completion Time and Date: 2020-02-08 01:08:31
# Total Avaible Search Result: 8300
# Query Completion Time and Date: 2020-02-08 01:09:02
# Total Avaible Search Result: 425
# Query Completion Time and Date: 2020-02-08 01:09:14
# Total Avaible Search Result: 997
# Query Completion Time and Date: 2020-02-08 01:09:42
# Total Avaible Search Result: 934
# Query Completion Time and Date: 2020-02-08 01:10:10
# Total Avaible Search Result: 251
# Query Completion Time and Date: 2020-02-08 01:10:18
# Total Avaible Search Result: 1800
# Query Completion Time and Date: 2020-02-08 01:10:49
# Total Avaible Search Result: 528
# Query Completion Time and Date: 2020-02-08 01:11:05
# Total Avaible Search Result: 20
# Query Completion Time and Date: 2020-02-08 01:11:06
# Total Avaible Search Result: 3000
# Query Completion Time and Date: 2020-02-08 01:11:37
# Total Avaible Search Result: 6000
# Query Completion Time and Date: 2020-02-08 01:12:09
# Total Avaible Search Result: 348
# Query Completion Time and Date: 2020-02-08 01:12:19
# Total Avaible Search Result: 14
# Query Completion Time and Date: 2020-02-08 01:12:19
# Total Avaible Search Result: 640
# Query Completion Time and Date: 2020-02-08 01:12:36
# Total Avaible Search Result: 1200
# Query Completion Time and Date: 2020-02-08 01:13:06
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 01:13:38
# Total Avaible Search Result: 6900
# Query Completion Time and Date: 2020-02-08 01:14:10
# Total Avaible Search Result: 4700
# Query Completion Time and Date: 2020-02-08 01:14:39
# Total Avaible Search Result: 1800
# Query Completion Time and Date: 2020-02-08 01:15:09
# Total Avaible Search Result: 94
# Query Completion Time and Date: 2020-02-08 01:15:13
# Total Avaible Search Result: 626
# Query Completion Time and Date: 2020-02-08 01:15:29
# Total Avaible Search Result: 27
# Query Completion Time and Date: 2020-02-08 01:15:29
# Total Avaible Search Result: 1400
# Query Completion Time and Date: 2020-02-08 01:15:59
# Total Avaible Search Result: 1100
# Query Completion Time and Date: 2020-02-08 01:16:28
# Total Avaible Search Result: 2200
# Query Completion Time and Date: 2020-02-08 01:17:00
# Total Avaible Search Result: 477
# Query Completion Time and Date: 2020-02-08 01:17:14
# Total Avaible Search Result: 3700
# Query Completion Time and Date: 2020-02-08 01:17:46
# Total Avaible Search Result: 227
# Query Completion Time and Date: 2020-02-08 01:17:52
# Total Avaible Search Result: 1100
# Query Completion Time and Date: 2020-02-08 01:18:19

# %% [markdown]
# ## Export results as .csv file

# %%
# results.to_csv('../data/raw.csv')

# %%
results.shape
# Out:
# (30293, 16)
